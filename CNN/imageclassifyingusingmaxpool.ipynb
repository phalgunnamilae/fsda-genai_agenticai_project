# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import cv2

# %%
img = image.load_img(r'C:\Users\nphal\fsda-genai_agenticai_project\CNN\training\happy\pic1.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=275x183>

# %%
i1 = cv2.imread(r'C:\Users\nphal\fsda-genai_agenticai_project\CNN\training\happy\pic1.jpg')
i1
# Out:
# array([[[213, 208, 207],
#         [213, 208, 207],
#         [213, 208, 207],
#         ...,
#         [214, 208, 209],
#         [214, 208, 209],
#         [214, 208, 209]],
#
#        [[213, 208, 207],
#         [213, 208, 207],
#         [213, 208, 207],
#         ...,
#         [214, 208, 209],
#         [214, 208, 209],
#         [214, 208, 209]],
#
#        [[213, 208, 207],
#         [213, 208, 207],
#         [213, 208, 207],
#         ...,
#         [214, 208, 209],
#         [214, 208, 209],
#         [214, 208, 209]],
#
#        ...,
#
#        [[175, 176, 186],
#         [176, 177, 187],
#         [178, 180, 188],
#         ...,
#         [214, 208, 209],
#         [214, 208, 209],
#         [214, 208, 209]],
#
#        [[168, 171, 185],
#         [169, 172, 186],
#         [171, 175, 186],
#         ...,
#         [214, 208, 209],
#         [214, 208, 209],
#         [214, 208, 209]],
#
#        [[165, 174, 188],
#         [165, 174, 188],
#         [167, 174, 189],
# ...

# %%
i1.shape
# Out:
# (183, 275, 3)

# %%
train = ImageDataGenerator(rescale=1/200)
validation = ImageDataGenerator (rescale=1/200)

# %%
train_dataset = train.flow_from_directory("C:/Users/nphal/fsda-genai_agenticai_project/CNN/training/happy",
                                          target_size = (200,200),
                                          batch_size = 32,
                                          class_mode = 'binary')

validation_dataset = validation.flow_from_directory("C:/Users/nphal/fsda-genai_agenticai_project/CNN/training/happy",
                                                    target_size = (200,200),
                                                    batch_size = 32,
                                                    class_mode = 'binary')
# Out:
# Found 0 images belonging to 0 classes.
# Found 0 images belonging to 0 classes.

# %%
train_dataset.class_indices
#train_dataset.classes
# Out:
# {}
