# %%
import numpy as np
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import classification_report
import warnings
warnings.filterwarnings('ignore')

# %%
# Step 1: Create an imbalanced binary classification dataset
X, y = make_classification(n_samples=1000, n_features=10, n_informative=2, n_redundant=8, 
                           weights=[0.9, 0.1], flip_y=0, random_state=42)

np.unique(y, return_counts=True)
# Out:
# (array([0, 1]), array([900, 100]))

# %%
# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y, random_state=42)

# %%
# Define the model hyperparameters
params = {
    "solver": "lbfgs",
    "max_iter": 1000,
    "multi_class": "auto",
    "random_state": 42,
}

# Train the model
lr = LogisticRegression(**params)
lr.fit(X_train, y_train)

# Predict on the test set
y_pred = lr.predict(X_test)

report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96       270
#            1       0.62      0.50      0.56        30
#
#     accuracy                           0.92       300
#    macro avg       0.79      0.73      0.76       300
# weighted avg       0.91      0.92      0.92       300

# %%
report_dict = classification_report(y_test, y_pred, output_dict=True)
report_dict
# Out:
# {'0': {'precision': 0.9456521739130435,
#   'recall': 0.9666666666666667,
#   'f1-score': 0.9560439560439561,
#   'support': 270.0},
#  '1': {'precision': 0.625,
#   'recall': 0.5,
#   'f1-score': 0.5555555555555556,
#   'support': 30.0},
#  'accuracy': 0.92,
#  'macro avg': {'precision': 0.7853260869565217,
#   'recall': 0.7333333333333334,
#   'f1-score': 0.7557997557997558,
#   'support': 300.0},
#  'weighted avg': {'precision': 0.9135869565217392,
#   'recall': 0.92,
#   'f1-score': 0.9159951159951161,
#   'support': 300.0}}

# %%
import mlflow

# %%
mlflow.set_experiment("1st Experiment")
mlflow.set_tracking_uri(uri="http://127.0.0.1:5000/")
#mlflow.set_tracking_uri("http://localhost:5000")

with mlflow.start_run():
    mlflow.log_params(params)
    mlflow.log_metrics({
        'accuracy': report_dict['accuracy'],
        'recall_class_0': report_dict['0']['recall'],
        'recall_class_1': report_dict['1']['recall'],
        'f1_score_macro': report_dict['macro avg']['f1-score']
    })
    mlflow.sklearn.log_model(lr, "Logistic Regression")
# Out:
# 2025/09/28 19:36:40 INFO mlflow.tracking.fluent: Experiment with name '1st Experiment' does not exist. Creating a new experiment.
# 2025/09/28 19:36:40 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run sassy-vole-559 at: http://127.0.0.1:5000/#/experiments/713622806695054289/runs/767eb384d6b047f4a0e3a64bea6c2287
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/713622806695054289
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 13
#       6 mlflow.log_params(params)
#       7 mlflow.log_metrics({
#       8     'accuracy': report_dict['accuracy'],
#       9     'recall_class_0': report_dict['0']['recall'],
#      10     'recall_class_1': report_dict['1']['recall'],
#      11     'f1_score_macro': report_dict['macro avg']['f1-score']
#      12 })
# ---> 13 mlflow.sklearn.log_model(lr, "Logistic Regression")
#
# File c:\Users\nphal\fsda-genai_agenticai_project\.venv\Lib\site-packages\mlflow\sklearn\__init__.py:426, in log_model(sk_model, artifact_path, conda_env, code_paths, serialization_format, registered_model_name, signature, input_example, await_registration_for, pip_requirements, extra_pip_requirements, pyfunc_predict_fn, metadata, params, tags, model_type, step, model_id, name)
#     334 @format_docstring(LOG_MODEL_PARAM_DOCS.format(package_name="scikit-learn"))
#     335 def log_model(
#     336     sk_model,
#    (...)    355     name: str | None = None,
#     356 ):
#     357     """
#     358     Log a scikit-learn model as an MLflow artifact for the current run. Produces an MLflow Model
#     359     containing the following flavors:
#    (...)    424
#     425     """
# --> 426     return Model.log(
#     427         artifact_path=artifact_path,
#     428         name=name,
#     429         flavor=mlflow.sklearn,
#     430         sk_model=sk_model,
#     431         conda_env=conda_env,
#     432         code_paths=code_paths,
#     433         serialization_format=serialization_format,
#     434         registered_model_name=registered_model_name,
#     435         signature=signature,
#     436         input_example=input_example,
#     437         await_registration_for=await_registration_for,
#     438         pip_requirements=pip_requirements,
#     439         extra_pip_requirements=extra_pip_requirements,
#     440         pyfunc_predict_fn=pyfunc_predict_fn,
#     441         metadata=metadata,
#     442         params=params,
#     443         tags=tags,
#     444         model_type=model_type,
#     445         step=step,
#     446         model_id=model_id,
#     447     )
#
# File c:\Users\nphal\fsda-genai_agenticai_project\.venv\Lib\site-packages\mlflow\models\model.py:1218, in Model.log(cls, artifact_path, flavor, registered_model_name, await_registration_for, metadata, run_id, resources, auth_policy, prompts, name, model_type, params, tags, step, model_id, **kwargs)
#    1206     prompts = [pr.uri if isinstance(pr, PromptVersion) else pr for pr in prompts]
#    1208 mlflow_model = cls(
#    1209     artifact_path=model.artifact_location,
#    1210     model_uuid=model.model_id,
#    (...)   1216     model_id=model.model_id,
#    1217 )
# -> 1218 flavor.save_model(path=local_path, mlflow_model=mlflow_model, **kwargs)
#    1219 # `save_model` calls `load_model` to infer the model requirements, which may result
#    1220 # in __pycache__ directories being created in the model directory.
#    1221 for pycache in Path(local_path).rglob("__pycache__"):
#
# File c:\Users\nphal\fsda-genai_agenticai_project\.venv\Lib\site-packages\mlflow\sklearn\__init__.py:274, in save_model(sk_model, path, conda_env, code_paths, mlflow_model, serialization_format, signature, input_example, pip_requirements, extra_pip_requirements, pyfunc_predict_fn, metadata)
#     271 # `PyFuncModel` only works for sklearn models that define a predict function
#     273 if hasattr(sk_model, pyfunc_predict_fn):
# --> 274     pyfunc.add_to_model(
#     275         mlflow_model,
#     276         loader_module="mlflow.sklearn",
#     277         model_path=model_data_subpath,
#     278         conda_env=_CONDA_ENV_FILE_NAME,
#     279         python_env=_PYTHON_ENV_FILE_NAME,
#     280         code=code_path_subdir,
#     281         predict_fn=pyfunc_predict_fn,
#     282     )
#     283 else:
#     284     _logger.warning(
#     285         f"Model was missing function: {pyfunc_predict_fn}. Not logging python_function flavor!"
#     286     )
#
# File c:\Users\nphal\fsda-genai_agenticai_project\.venv\Lib\site-packages\mlflow\utils\lazy_load.py:41, in LazyLoader.__getattr__(self, item)
#      40 def __getattr__(self, item):
# ---> 41     module = self._load()
#      42     return getattr(module, item)
#
# File c:\Users\nphal\fsda-genai_agenticai_project\.venv\Lib\site-packages\mlflow\utils\lazy_load.py:30, in LazyLoader._load(self)
#      27     return self._module
#      29 # Import the target module and insert it into the parent's namespace
# ---> 30 module = importlib.import_module(self.__name__)
#      31 self._parent_module_globals[self._local_name] = module
#      32 sys.modules[self._local_name] = module
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\importlib\__init__.py:88, in import_module(name, package)
#      86             break
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1331, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:935, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:1026, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:488, in _call_with_frames_removed(f, *args, **kwds)
#
# File c:\Users\nphal\fsda-genai_agenticai_project\.venv\Lib\site-packages\mlflow\pyfunc\__init__.py:429
#     427 import mlflow
#     428 import mlflow.models.signature
# --> 429 import mlflow.pyfunc.loaders
#     430 import mlflow.pyfunc.model
#     431 from mlflow.entities.model_registry.prompt import Prompt
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1331, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:935, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:1022, in exec_module(self, module)
#
# File <frozen importlib._bootstrap_external>:1112, in get_code(self, fullname)
#
# File <frozen importlib._bootstrap_external>:1235, in path_stats(self, path)
#
# File <frozen importlib._bootstrap_external>:152, in _path_stat(path)
#
# KeyboardInterrupt:
