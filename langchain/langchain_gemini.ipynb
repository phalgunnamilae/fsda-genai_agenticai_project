# %%
#pip install -U langchain-google-genai

# %%
import getpass
import os

if not os.environ.get("GOOGLE_API_KEY"):
  os.environ["GOOGLE_API_KEY"] = "AIzaSyCmsmNqErhSOBBBX4w9E1cJ-QEA2kDGTxc"

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model("gemini-2.0-flash", model_provider="google_genai")

# %%
model.invoke("How many continents are there")
# Out:
# AIMessage(content='There are seven continents:\n\n*   **Africa**\n*   **Antarctica**\n*   **Asia**\n*   **Australia**\n*   **Europe**\n*   **North America**\n*   **South America**', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.0-flash', 'safety_ratings': [], 'grounding_metadata': {}, 'model_provider': 'google_genai'}, id='lc_run--eb30fd0d-4f3f-43e9-8a75-afef8b21179c-0', usage_metadata={'input_tokens': 5, 'output_tokens': 50, 'total_tokens': 55, 'input_token_details': {'cache_read': 0}})

# %%
# Prompt template

# %%
from langchain_core.prompts import ChatPromptTemplate

system_template =  "Translate the following from English into {language}"

prompt_template = ChatPromptTemplate.from_messages(
    [("system", system_template), ("user", "{text}")]
)

# %%
prompt = prompt_template.invoke({"language": "telugu", "text": "How are you"})
prompt
# Out:
# ChatPromptValue(messages=[SystemMessage(content='Translate the following from English into telugu', additional_kwargs={}, response_metadata={}), HumanMessage(content='How are you', additional_kwargs={}, response_metadata={})])

# %%
prompt.to_messages()
# Out:
# [SystemMessage(content='Translate the following from English into telugu', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='How are you', additional_kwargs={}, response_metadata={})]

# %%
response = model.invoke(prompt)
print(response.content)
# Out:
# మీరు ఎలా ఉన్నారు? (Meeru ela unnaaru?)
